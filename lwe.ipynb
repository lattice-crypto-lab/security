# %%
from estimator.estimator import *
from utils import *

# %%
# LWE
n = 512

# q = 2**13
# lwe_key_type = "Binary"
# lwe_noise_stddev = 3.2
# lwe_key_distribution = ND.SparseBinary(n // 2, n)

q = 2**16
lwe_key_type = "Ternary"
lwe_noise_stddev = 4 * (2**2)
lwe_key_distribution = ND.SparseTernary(n // 4, n // 4, n)

# %%
check_security_with_data(
    n, q, lwe_key_type, lwe_key_distribution, lwe_noise_stddev
)
# Out:
# LWEParameters(n=512, q=65536, Xs=T(p=128, m=128, n=512), Xe=D(σ=16.00), m=+Infinity, tag=None)
# usvp                 :: rop: ≈2^131.8, red: ≈2^131.8, δ: 1.004356, β: 351, d: 950, tag: usvp
# bdd                  :: rop: ≈2^129.9, red: ≈2^128.9, svp: ≈2^128.8, β: 342, η: 384, d: 822, tag: bdd
# dual                 :: rop: ≈2^136.5, mem: ≈2^84.7, m: 472, β: 367, d: 984, ↻: 1, tag: dual
# shape: (1, 7)
# ┌───────────┬─────────┬──────────────┬───────────────┬──────────────┬───────────────┬──────────────┐
# │ dimension ┆ modulus ┆ secret_distr ┆ secret_stddev ┆ noise_stddev ┆ security_bits ┆ datetime     │
# │ ---       ┆ ---     ┆ ---          ┆ ---           ┆ ---          ┆ ---           ┆ ---          │
# │ u64       ┆ str     ┆ str          ┆ f64           ┆ f64          ┆ f64           ┆ datetime[μs] │
# ╞═══════════╪═════════╪══════════════╪═══════════════╪══════════════╪═══════════════╪══════════════╡
# │ 512       ┆ 65536   ┆ Ternary      ┆ 0.707107      ┆ 16.0         ┆ 129.884894    ┆ 2026-03-25   │
# │           ┆         ┆              ┆               ┆              ┆               ┆ 19:53:07.858 │
# │           ┆         ┆              ┆               ┆              ┆               ┆ 422          │
# └───────────┴─────────┴──────────────┴───────────────┴──────────────┴───────────────┴──────────────┘
